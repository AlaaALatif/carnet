# %% [markdown]
# # A Quick Guide to set up fastai on your Collaboratory Notebook

# %% [markdown]
# Uncomment below if you want to kill the VM instance

# %%
#!kill -9 -1

# %%
# !nvidia-smi

# %% [markdown]
# ## Check GPU is available. If not, click Runtime > Change runtime type > Python3, GPU > Save

# %%
import tensorflow as tf
tf.test.gpu_device_name()

# %% [markdown]
# ## Download and Install Pytorch

# %%
# !pip install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl && pip install torchvision

# %% [markdown]
# ## Download and Install fastai

# %%
# !pip install fastai

# %% [markdown]
# ## Install necessary libraries

# %%
# !apt update && apt install -y libsm6 libxext6
